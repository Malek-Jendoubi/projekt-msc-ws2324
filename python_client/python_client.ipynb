# %%
import pandas as pd
import matplotlib.pyplot as plt

FILE = "./pressure_log.csv"

# Load the CSV file into a DataFrame. Adjust 'path_to_your_csv.csv' to your file's actual path.
df = pd.read_csv(FILE, sep=" ")
df.head()


X_Data = df['timestamp'] 
Y_Data = df['pressure_values']

plt.plot(X_Data,Y_Data, 'r-', lw=1)
